# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# ### Data Description

# %% [markdown]
# U.S. Chronic Disease Indicators
#
# Last Updated: March 9, 2024
#
# Source: U.S. Chronic Disease Indicators - data.gov https://catalog.data.gov/dataset/u-s-chronic-disease-indicators
#
# The dataset includes over 300,000 rows of chronic disease indicator data collected from U.S. states and territories. It encompasses data by topic (e.g., Cancer, Health Status), location, stratification (e.g., by race or gender), and confidence intervals for measurements.

# %% [markdown]
# ### Load the Data

# %%
chronic_diseaseUS = pd.read_csv('U.S._Chronic_Disease_Indicators.csv')
chronic_diseaseUS.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DataValueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'Geolocation', 'LocationID', 'TopicID', 'QuestionID', 'ResponseID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %% [markdown]
# ### Generate two tables of data as part of your database.
#
# **Database Schema Plan**
# To do that we will we split the chronic disease dataset  into two tables:
#
# **Table 1: locations**
# LocationID (Primary Key)
#
# LocationAbbr
#
# LocationDesc
#
# Geolocation
#
# **Table 2: chronic_data**
# RecordID (Primary Key - auto-generated)
#
# YearStart, YearEnd
#
# LocationID (Foreign Key from locations)
#
# Topic, Question, DataValue, LowConfidenceLimit, HighConfidenceLimit
#
# StratificationCategory1, Stratification1
#
# Next, I’ll set up the SQLite database, populate these tables, and perform the requested queries and operations.

# %%
# Create a new SQLite database
conn = sqlite3.connect('chronic_disease.db')
cursor = conn.cursor()

# %%
# Create tables
cursor.execute('''
CREATE TABLE IF NOT EXISTS locations (
    LocationID INTEGER PRIMARY KEY,
    LocationAbbr TEXT NOT NULL,
    LocationDesc TEXT,
    Geolocation INTEGER
)''')


cursor.execute('''
CREATE TABLE IF NOT EXISTS chronic_data ( 
RECORDID INTEGER PRIMARY KEY ,
    YearStart INTEGER, 
    YearEnd INTEGER ,
    LocationID TEXT NOT NULL,
    Topic TEXT , 
    Question TEXT,
    DataValue REAL, 
    LowConfidenceLimit REAL,
    HighConfidenceLimit REAL,
    StratificationCategory1 TEXT, 
    Stratification1 TEXT ,
    FOREIGN KEY (LocationID) REFERENCES authors(LocationID)
)
''')

# %% [markdown]
# ### Add rows of data to the table

# %%
locations_df = chronic_diseaseUS[["LocationID", "LocationAbbr", "LocationDesc", "Geolocation"]]
locations_df

chronic_data = chronic_diseaseUS[[
    "YearStart", "YearEnd", "LocationID", "Geolocation",
    "Topic", "Question", "DataValue", "LowConfidenceLimit", "HighConfidenceLimit",
    "StratificationCategory1", "Stratification1"
]]
chronic_data = chronic_data.drop_duplicates()
locations_df = locations_df.drop_duplicates()


# Insert the  value into the location table
for index, row in locations_df.iterrows():
    cursor.execute('''
    INSERT OR IGNORE INTO locations (LocationID, LocationAbbr, LocationDesc, Geolocation) VALUES (?, ?, ?, ?)
    ''', (row['LocationID'], row['LocationAbbr'], row['LocationDesc'], row['Geolocation']))
    
    
# 2. Insert value to chronic_data into  table row by row
for index, row in chronic_data.iterrows():
    cursor.execute('''
    INSERT OR IGNORE INTO chronic_data (
        YearStart, YearEnd, LocationID,
        Topic, Question, DataValue, LowConfidenceLimit, HighConfidenceLimit,
        StratificationCategory1, Stratification1
    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', (
        row['YearStart'], row['YearEnd'], row['LocationID'], row['Topic'], row['Question'],
        row['DataValue'], row['LowConfidenceLimit'], row['HighConfidenceLimit'],
        row['StratificationCategory1'], row['Stratification1']
    ))
    

# 3. Commit the changes
conn.commit()

# %%
cursor.execute('''
SELECT *
    FROM locations;
''')

cursor.fetchall()
# Out:
# [(1, 'AL', 'Alabama', 'POINT (-86.63186076199969 32.84057112200048)'),
#  (2, 'AK', 'Alaska', 'POINT (-147.72205903599973 64.84507995700051)'),
#  (4, 'AZ', 'Arizona', 'POINT (-111.76381127699972 34.865970280000454)'),
#  (5, 'AR', 'Arkansas', 'POINT (-92.27449074299966 34.74865012400045)'),
#  (6, 'CA', 'California', 'POINT (-120.99999953799971 37.63864012300047)'),
#  (8, 'CO', 'Colorado', 'POINT (-106.13361092099967 38.843840757000464)'),
#  (9, 'CT', 'Connecticut', 'POINT (-72.64984095199964 41.56266102000046)'),
#  (10, 'DE', 'Delaware', 'POINT (-75.57774116799965 39.008830667000495)'),
#  (11, 'DC', 'District of Columbia', 'POINT (-77.036871 38.907192)'),
#  (12, 'FL', 'Florida', 'POINT (-81.92896053899966 28.932040377000476)'),
#  (13, 'GA', 'Georgia', 'POINT (-83.62758034599966 32.83968109300048)'),
#  (15, 'HI', 'Hawaii', 'POINT (-157.85774940299973 21.304850435000446)'),
#  (16, 'ID', 'Idaho', 'POINT (-114.3637300419997 43.682630005000476)'),
#  (17, 'IL', 'Illinois', 'POINT (-88.99771017799969 40.48501028300046)'),
#  (18, 'IN', 'Indiana', 'POINT (-86.14996019399968 39.766910452000445)'),
#  (19, 'IA', 'Iowa', 'POINT (-93.81649055599968 42.46940091300047)'),
#  (20, 'KS', 'Kansas', 'POINT (-98.20078122699965 38.34774030000045)'),
#  (21, 'KY', 'Kentucky', 'POINT (-84.77497104799966 37.645970271000465)'),
#  (22, 'LA', 'Louisiana', 'POINT (-92.44568007099969 31.31266064400046)'),
#  (23, 'ME', 'Maine', 'POINT (-68.98503133599962 45.254228894000505)'),
#  (24, 'MD', 'Maryland', 'POINT (-76.60926011099963 39.29058096400047)'),
#  (25, 'MA', 'Massachusetts', 'POINT (-72.08269067499964 42.27687047000046)'),
#  (26, 'MI', 'Michigan', 'POINT (-84.71439026999968 44.6613195430005)'),
#  (27, 'MN', 'Minnesota', 'POINT (-94.79420050299967 46.35564873600049)'),
#  (28, 'MS', 'Mississippi', 'POINT (-89.53803082499968 32.745510099000455)'),
#  (29, 'MO', 'Missouri', 'POINT (-92.56630005299968 38.635790776000476)'),
#  (30, 'MT', 'Montana', 'POINT (-109.42442064499971 47.06652897200047)'),
#  (31, 'NE', 'Nebraska', 'POINT (-99.36572062299967 41.6410409880005)'),
#  (32, 'NV', 'Nevada', 'POINT (-117.07184056399967 39.493240390000494)'),
#  (33, 'NH', 'New Hampshire', 'POINT (-71.50036091999965 43.65595011300047)'),
#  (34, 'NJ', 'New Jersey', 'POINT (-74.27369128799967 40.13057004800049)'),
#  (35, 'NM', 'New Mexico', 'POINT (-106.24058098499967 34.52088095200048)'),
#  (36, 'NY', 'New York', 'POINT (-75.54397042699964 42.82700103200045)'),
#  (37, 'NC', 'North Carolina', 'POINT (-79.15925046299964 35.466220975000454)'),
#  (38, 'ND', 'North Dakota', 'POINT (-100.11842104899966 47.47531977900047)'),
#  (39, 'OH', 'Ohio', 'POINT (-82.40426005599966 40.06021014100048)'),
#  (40, 'OK', 'Oklahoma', 'POINT (-97.52107021399968 35.47203135600046)'),
#  (41, 'OR', 'Oregon', 'POINT (-120.15503132599969 44.56744942400047)'),
#  (42, 'PA', 'Pennsylvania', 'POINT (-77.86070029399963 40.79373015200048)'),
#  (44, 'RI', 'Rhode Island', 'POINT (-71.52247031399963 41.70828019300046)'),
#  (45, 'SC', 'South Carolina', 'POINT (-81.04537120699968 33.998821303000454)'),
#  (46, 'SD', 'South Dakota', 'POINT (-100.3735306369997 44.353130053000484)'),
#  (47, 'TN', 'Tennessee', 'POINT (-85.77449091399967 35.68094058000048)'),
#  (48, 'TX', 'Texas', 'POINT (-99.42677020599967 31.827240407000488)'),
#  (49, 'UT', 'Utah', 'POINT (-111.58713063499971 39.360700171000474)'),
#  (50, 'VT', 'Vermont', 'POINT (-72.51764079099962 43.62538123900049)'),
#  (51, 'VA', 'Virginia', 'POINT (-78.45789046299967 37.54268067400045)'),
#  (53, 'WA', 'Washington', 'POINT (-120.47001078999972 47.52227862900048)'),
#  (54, 'WV', 'West Virginia', 'POINT (-80.71264013499967 38.66551020200046)'),
#  (55, 'WI', 'Wisconsin', 'POINT (-89.81637074199966 44.39319117400049)'),
#  (56, 'WY', 'Wyoming', 'POINT (-108.10983035299967 43.23554134300048)'),
#  (66, 'GU', 'Guam', 'POINT (144.793731 13.444304)'),
#  (72, 'PR', 'Puerto Rico', 'POINT (-66.590149 18.220833)'),
#  (78, 'VI', 'Virgin Islands', 'POINT (-64.896335 18.335765)')]

# %%
cursor.execute('''
SELECT *
    FROM chronic_data;
''')

cursor.fetchall()
# Out:
# [(2019,
#   2019,
#   '5',
#   'Diabetes',
#   'Diabetes among adults',
#   13.6,
#   12.1,
#   15.4,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '16',
#   'Diabetes',
#   'Diabetes among adults',
#   10.6,
#   9.1,
#   12.2,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '18',
#   'Sleep',
#   'Short sleep duration among high school students',
#   None,
#   None,
#   None,
#   'Grade',
#   'Grade 12'),
#  (2019,
#   2019,
#   '19',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   54.0,
#   None,
#   None,
#   'Overall',
#   'Overall'),
#  (2019,
#   2019,
#   '19',
#   'Asthma',
#   'Current asthma among adults',
#   10.3,
#   9.1,
#   11.7,
#   'Age',
#   'Age 18-44'),
#  (2019,
#   2019,
#   '19',
#   'Diabetes',
#   'Diabetes mortality among all people, underlying or contributing cause',
#   54.0,
#   None,
#   None,
#   'Age',
#   'Age 0-44'),
#  (2019,
#   2019,
#   '19',
#   'Health Status',
#   'Recent activity limitation among adults',
#   2.3,
#   2.1,
#   2.5,
#   'Sex',
#   'Female'),
#  (2019,
#   2019,
#   '19',
#   'Mental Health',
#   'Depression among adults',
#   31.0,
#   20.6,
#   43.7,
#   'Race/Ethnicity',
#   'Multiracial, non-Hispanic'),
#  (2019,
#   2019,
#   '20',
#   'Diabetes',
#   'Diabetes mortality among all people, underlying or contributing cause',
#   524.0,
#   None,
#   None,
#   'Age',
#   'Age 45-64'),
#  (2019,
#   2019,
#   '22',
#   'Mental Health',
#   'Depression among adults',
#   29.3,
#   20.7,
#   39.6,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2019,
#   2019,
#   '24',
#   'Alcohol',
#   'Alcohol use among high school students',
#   21.0,
#   19.6,
#   22.4,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '24',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   28.0,
#   None,
#   None,
#   'Age',
#   'Age >=65'),
#  (2019,
#   2019,
#   '24',
#   'Mental Health',
#   'Depression among adults',
#   19.2,
#   18.0,
#   20.4,
#   'Sex',
#   'Female'),
#  (2019,
#   2019,
#   '26',
#   'Health Status',
#   'Life expectancy at birth',
#   80.3,
#   80.2,
#   80.4,
#   'Sex',
#   'Female'),
#  (2019,
#   2019,
#   '27',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   44.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2019,
#   2019,
#   '28',
#   'Arthritis',
#   'Severe joint pain among adults with arthritis',
#   37.6,
#   32.9,
#   42.7,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '29',
#   'Tobacco',
#   'Current cigarette smoking among adults',
#   20.6,
#   18.7,
#   22.6,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '31',
#   'Diabetes',
#   'Diabetes among adults',
#   9.4,
#   8.7,
#   10.3,
#   'Sex',
#   'Female'),
#  (2019,
#   2019,
#   '31',
#   'Diabetes',
#   'Diabetes mortality among all people, underlying or contributing cause',
#   992.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2019,
#   2019,
#   '32',
#   'Alcohol',
#   'Alcohol use among high school students',
#   29.0,
#   24.3,
#   34.2,
#   'Grade',
#   'Grade 11'),
#  (2019,
#   2019,
#   '32',
#   'Arthritis',
#   'Arthritis among adults',
#   46.1,
#   41.3,
#   51.0,
#   'Age',
#   'Age >=65'),
#  (2019,
#   2019,
#   '32',
#   'Asthma',
#   'Current asthma among adults',
#   7.1,
#   5.6,
#   9.0,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '33',
#   'Arthritis',
#   'Arthritis among adults',
#   22.7,
#   20.7,
#   24.8,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '33',
#   'Disability',
#   'Adults with any disability',
#   24.4,
#   22.2,
#   26.8,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '34',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   66.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2019,
#   2019,
#   '34',
#   'Diabetes',
#   'Diabetes among adults',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '36',
#   'Alcohol',
#   'Binge drinking prevalence among adults',
#   20.8,
#   19.3,
#   22.3,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '36',
#   'Arthritis',
#   'Physical inactivity among adults with arthritis',
#   26.8,
#   23.7,
#   30.2,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '37',
#   'Diabetes',
#   'Diabetes mortality among all people, underlying or contributing cause',
#   4834.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '37',
#   'Mental Health',
#   'Depression among adults',
#   15.1,
#   13.3,
#   17.1,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '38',
#   'Asthma',
#   'Current asthma among adults',
#   10.5,
#   8.6,
#   12.7,
#   'Age',
#   'Age 18-44'),
#  (2019,
#   2019,
#   '38',
#   'Disability',
#   'Adults with any disability',
#   23.1,
#   21.1,
#   25.3,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '40',
#   'Arthritis',
#   'Arthritis among adults',
#   27.7,
#   26.1,
#   29.4,
#   'Sex',
#   'Female'),
#  (2019,
#   2019,
#   '40',
#   'Diabetes',
#   'Diabetes among adults',
#   11.8,
#   8.7,
#   15.8,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2019,
#   2019,
#   '40',
#   'Disability',
#   'Adults with any disability',
#   35.0,
#   32.8,
#   37.2,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '40',
#   'Mental Health',
#   'Depression among adults',
#   23.0,
#   21.6,
#   24.4,
#   'Overall',
#   'Overall'),
#  (2019,
#   2019,
#   '40',
#   'Sleep',
#   'Short sleep duration among high school students',
#   83.0,
#   77.7,
#   87.3,
#   'Grade',
#   'Grade 11'),
#  (2019,
#   2019,
#   '41',
#   'Tobacco',
#   'Current cigarette smoking among adults',
#   15.4,
#   13.9,
#   17.1,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '72',
#   'Alcohol',
#   'Alcohol use among high school students',
#   26.4,
#   21.3,
#   32.2,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '72',
#   'Immunization',
#   'Influenza vaccination among adults',
#   27.3,
#   25.1,
#   29.7,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '44',
#   'Diabetes',
#   'Diabetes among adults',
#   21.4,
#   19.2,
#   23.7,
#   'Age',
#   'Age >=65'),
#  (2019,
#   2019,
#   '44',
#   'Tobacco',
#   'Current cigarette smoking among adults',
#   15.3,
#   13.3,
#   17.6,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '46',
#   'Asthma',
#   'Current asthma among adults',
#   9.2,
#   7.8,
#   10.9,
#   'Overall',
#   'Overall'),
#  (2019,
#   2019,
#   '48',
#   'Disability',
#   'Adults with any disability',
#   28.1,
#   26.6,
#   29.7,
#   'Overall',
#   'Overall'),
#  (2019,
#   2019,
#   '59',
#   'Arthritis',
#   'Physical inactivity among adults with arthritis',
#   27.0,
#   25.6,
#   28.5,
#   'Age',
#   'Age 18-44'),
#  (2019,
#   2019,
#   '59',
#   'Diabetes',
#   'Diabetes mortality among all people, underlying or contributing cause',
#   157805.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2019,
#   2019,
#   '50',
#   'Alcohol',
#   'Binge drinking intensity among adults who binge drink',
#   7.7,
#   7.0,
#   8.7,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2019,
#   2019,
#   '78',
#   'Diabetes',
#   'Diabetes among adults',
#   None,
#   None,
#   None,
#   'Age',
#   'Age >=65'),
#  (2020,
#   2020,
#   '23',
#   'Mental Health',
#   'Depression among adults',
#   16.0,
#   14.4,
#   17.8,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '31',
#   'Tobacco',
#   'Current cigarette smoking among adults',
#   15.6,
#   14.3,
#   16.9,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '32',
#   'Alcohol',
#   'Chronic liver disease mortality among all people, underlying cause',
#   98.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2020,
#   2020,
#   '32',
#   'Asthma',
#   'Current asthma among adults',
#   8.0,
#   6.1,
#   10.5,
#   'Age',
#   'Age 18-44'),
#  (2020,
#   2020,
#   '33',
#   'Disability',
#   'Adults with any disability',
#   16.9,
#   14.4,
#   19.8,
#   'Age',
#   'Age 18-44'),
#  (2020,
#   2020,
#   '35',
#   'Tobacco',
#   'Current cigarette smoking among adults',
#   18.9,
#   16.5,
#   21.4,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '36',
#   'Tobacco',
#   'Current cigarette smoking among adults',
#   15.3,
#   13.9,
#   16.7,
#   'Age',
#   'Age 45-64'),
#  (2020,
#   2020,
#   '36',
#   'Tobacco',
#   'Current cigarette smoking among adults',
#   14.7,
#   13.4,
#   16.0,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '37',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   47.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '38',
#   'Health Status',
#   '2 or more chronic conditions among adults',
#   14.7,
#   13.0,
#   16.5,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '39',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   49.0,
#   None,
#   None,
#   'Age',
#   'Age 45-64'),
#  (2020,
#   2020,
#   '39',
#   'Asthma',
#   'Current asthma among adults',
#   11.3,
#   10.2,
#   12.5,
#   'Age',
#   'Age 45-64'),
#  (2020,
#   2020,
#   '39',
#   'Oral Health',
#   'No teeth lost among adults aged 18-64 years',
#   64.1,
#   62.2,
#   65.9,
#   'Sex',
#   'Female'),
#  (2020,
#   2020,
#   '41',
#   'Sleep',
#   'Short sleep duration among adults',
#   29.8,
#   27.8,
#   32.0,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '42',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   73.0,
#   None,
#   None,
#   'Age',
#   'Age >=65'),
#  (2020,
#   2020,
#   '42',
#   'Immunization',
#   'Influenza vaccination among adults',
#   50.1,
#   48.3,
#   52.0,
#   'Overall',
#   'Overall'),
#  (2020,
#   2020,
#   '72',
#   'Health Status',
#   'Recent activity limitation among adults',
#   2.0,
#   1.7,
#   2.2,
#   'Sex',
#   'Female'),
#  (2020,
#   2020,
#   '72',
#   'Tobacco',
#   'Current cigarette smoking among adults',
#   10.5,
#   9.1,
#   12.0,
#   'Overall',
#   'Overall'),
#  (2020,
#   2020,
#   '44',
#   'Diabetes',
#   'Diabetes among adults',
#   10.9,
#   9.4,
#   12.6,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '47',
#   'Disability',
#   'Adults with any disability',
#   33.9,
#   30.8,
#   37.1,
#   'Age',
#   'Age 45-64'),
#  (2020,
#   2020,
#   '48',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   136.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2020,
#   2020,
#   '48',
#   'Disability',
#   'Adults with any disability',
#   24.7,
#   22.4,
#   27.0,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '59',
#   'Disability',
#   'Adults with any disability',
#   26.7,
#   26.1,
#   27.3,
#   'Age',
#   'Age 45-64'),
#  (2020,
#   2020,
#   '59',
#   'Health Status',
#   'Fair or poor self-rated health status among adults',
#   13.5,
#   13.2,
#   13.9,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '59',
#   'Oral Health',
#   'All teeth lost among adults aged 65 years and older',
#   13.4,
#   12.6,
#   14.1,
#   'Sex',
#   'Male'),
#  (2020,
#   2020,
#   '49',
#   'Mental Health',
#   'Depression among adults',
#   30.1,
#   28.6,
#   31.7,
#   'Sex',
#   'Female'),
#  (2020,
#   2020,
#   '50',
#   'Alcohol',
#   'Chronic liver disease mortality among all people, underlying cause',
#   44.0,
#   None,
#   None,
#   'Age',
#   'Age 45-64'),
#  (2020,
#   2020,
#   '50',
#   'Diabetes',
#   'Diabetes mortality among all people, underlying or contributing cause',
#   895.0,
#   None,
#   None,
#   'Overall',
#   'Overall'),
#  (2020,
#   2020,
#   '51',
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   51.0,
#   None,
#   None,
#   'Age',
#   'Age >=65'),
#  (2020,
#   2020,
#   '54',
#   'Asthma',
#   'Current asthma among adults',
#   13.8,
#   11.8,
#   16.0,
#   'Age',
#   'Age 18-44'),
#  (2020,
#   2020,
#   '54',
#   'Diabetes',
#   'Diabetes among adults',
#   17.2,
#   11.5,
#   24.8,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2020,
#   2020,
#   '55',
#   'Mental Health',
#   'Depression among adults',
#   26.5,
#   24.1,
#   29.1,
#   'Sex',
#   'Female'),
#  (2020,
#   2020,
#   '56',
#   'Alcohol',
#   'Chronic liver disease mortality among all people, underlying cause',
#   103.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '1',
#   'Asthma',
#   'Current asthma among adults',
#   14.2,
#   12.3,
#   16.4,
#   'Sex',
#   'Female'),
#  (2021,
#   2021,
#   '1',
#   'Diabetes',
#   'Diabetes among adults',
#   13.7,
#   12.1,
#   15.4,
#   'Sex',
#   'Female'),
#  (2021,
#   2021,
#   '1',
#   'Disability',
#   'Adults with any disability',
#   29.6,
#   26.8,
#   32.5,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '1',
#   'Mental Health',
#   'Depression among adults',
#   27.4,
#   17.8,
#   39.7,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2021,
#   2021,
#   '5',
#   'Asthma',
#   'Current asthma among adults',
#   8.0,
#   6.5,
#   9.8,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '5',
#   'Health Status',
#   'Frequent physical distress among adults',
#   14.6,
#   13.4,
#   16.0,
#   'Overall',
#   'Overall'),
#  (2021,
#   2021,
#   '5',
#   'Health Status',
#   'Recent activity limitation among adults',
#   3.4,
#   2.9,
#   3.9,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '6',
#   'Health Status',
#   'Frequent physical distress among adults',
#   9.1,
#   8.0,
#   10.4,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '10',
#   'Arthritis',
#   'Arthritis among adults',
#   31.9,
#   29.3,
#   34.6,
#   'Sex',
#   'Female'),
#  (2021,
#   2021,
#   '12',
#   'Arthritis',
#   'Physical inactivity among adults with arthritis',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '12',
#   'Disability',
#   'Adults with any disability',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2021,
#   2021,
#   '12',
#   'Mental Health',
#   'Depression among adults',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2021,
#   2021,
#   '13',
#   'Health Status',
#   'Recent activity limitation among adults',
#   3.0,
#   2.7,
#   3.4,
#   'Sex',
#   'Female'),
#  (2021,
#   2021,
#   '66',
#   'Arthritis',
#   'Physical inactivity among adults with arthritis',
#   48.5,
#   29.9,
#   67.6,
#   'Age',
#   'Age 45-64'),
#  (2021,
#   2021,
#   '66',
#   'Asthma',
#   'Current asthma among adults',
#   4.7,
#   3.0,
#   7.1,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '66',
#   'Nutrition, Physical Activity, and Weight Status',
#   'Obesity among adults',
#   42.0,
#   33.3,
#   51.3,
#   'Age',
#   'Age 45-64'),
#  (2021,
#   2021,
#   '15',
#   'Arthritis',
#   'Physical inactivity among adults with arthritis',
#   22.9,
#   18.9,
#   27.5,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '18',
#   'Diabetes',
#   'Diabetes among adults',
#   12.9,
#   11.9,
#   14.0,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '19',
#   'Mental Health',
#   'Depression among adults',
#   12.0,
#   10.8,
#   13.3,
#   'Sex',
#   'Male'),
#  (2021,
#   2021,
#   '59',
#   'Alcohol',
#   'Alcohol use among high school students',
#   22.9,
#   19.8,
#   26.2,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2021,
#   2021,
#   '59',
#   'Health Status',
#   'Fair or poor self-rated health status among adults',
#   15.5,
#   15.2,
#   15.9,
#   'Sex',
#   'Male'),
#  (2022,
#   2022,
#   '22',
#   'Asthma',
#   'Current asthma among adults',
#   6.9,
#   5.6,
#   8.4,
#   'Sex',
#   'Male'),
#  (2022,
#   2022,
#   '28',
#   'Arthritis',
#   'Arthritis among adults',
#   30.9,
#   29.3,
#   32.6,
#   'Overall',
#   'Overall'),
#  (2022,
#   2022,
#   '28',
#   'Asthma',
#   'Current asthma among adults',
#   7.3,
#   5.7,
#   9.2,
#   'Sex',
#   'Male'),
#  (2022,
#   2022,
#   '31',
#   'Disability',
#   'Adults with any disability',
#   23.0,
#   21.2,
#   24.9,
#   'Sex',
#   'Male'),
#  (2022,
#   2022,
#   '31',
#   'Oral Health',
#   'No teeth lost among adults aged 18-64 years',
#   68.7,
#   66.1,
#   71.1,
#   'Sex',
#   'Male'),
#  (2022,
#   2022,
#   '40',
#   'Immunization',
#   'Influenza vaccination among adults',
#   67.8,
#   65.2,
#   70.3,
#   'Age',
#   'Age >=65'),
#  (2022,
#   2022,
#   '40',
#   'Mental Health',
#   'Frequent mental distress among adults',
#   23.5,
#   21.3,
#   25.8,
#   'Age',
#   'Age 18-44'),
#  (2022,
#   2022,
#   '41',
#   'Arthritis',
#   'Arthritis among adults',
#   55.4,
#   52.3,
#   58.5,
#   'Age',
#   'Age >=65'),
#  (2022,
#   2022,
#   '41',
#   'Immunization',
#   'Influenza vaccination among adults',
#   31.9,
#   27.4,
#   36.8,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2022,
#   2022,
#   '59',
#   'Sleep',
#   'Short sleep duration among adults',
#   38.6,
#   38.0,
#   39.1,
#   'Age',
#   'Age 45-64'),
#  (2015,
#   2019,
#   '39',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   34395.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '16',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   123.1,
#   100.5,
#   149.1,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '56',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   12.2,
#   11.0,
#   13.5,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '5',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   548.3,
#   543.3,
#   553.4,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '34',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   73.2,
#   70.6,
#   75.9,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '8',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '1',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '16',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '36',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   14.9,
#   14.3,
#   15.5,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '38',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   18.4,
#   16.5,
#   20.4,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '48',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   3431.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '37',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2016,
#   2020,
#   '9',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   139.9,
#   138.2,
#   141.6,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2016,
#   2020,
#   '22',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   46.1,
#   44.5,
#   47.7,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '28',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   11119.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '17',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   14.1,
#   13.8,
#   14.5,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '51',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   20711.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '21',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   226.6,
#   223.9,
#   229.4,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '33',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   101.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '55',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   20.6,
#   19.9,
#   21.4,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '36',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   38.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '10',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   161.3,
#   158.2,
#   164.5,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '12',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   158.3,
#   156.2,
#   160.4,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '36',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   400.4,
#   397.2,
#   403.5,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '37',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   30165.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '9',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '10',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '20',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   191.5,
#   185.1,
#   198.2,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '48',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   1.4,
#   1.1,
#   1.9,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '10',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '4',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   23.5,
#   20.3,
#   26.9,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '19',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   3.9,
#   2.3,
#   6.0,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '29',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   37.3,
#   36.5,
#   38.1,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '40',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   12.9,
#   9.5,
#   16.9,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '30',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   426.4,
#   419.1,
#   433.7,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '27',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   13.2,
#   10.7,
#   16.1,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '16',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   486.1,
#   479.9,
#   492.4,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '28',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   57.9,
#   48.0,
#   69.0,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '12',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   54.3,
#   53.8,
#   54.7,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '56',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   18.8,
#   16.8,
#   21.1,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '11',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   33.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '29',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   14.2,
#   13.9,
#   14.6,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '18',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '2',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   11.6,
#   6.7,
#   18.6,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '5',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   526.5,
#   521.6,
#   531.4,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '6',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   450.8,
#   449.5,
#   452.1,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '48',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   371.3,
#   355.2,
#   388.0,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '2',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   13.4,
#   12.2,
#   14.6,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '31',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   19.8,
#   18.7,
#   21.0,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '50',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '29',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   69.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '30',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '27',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   20.0,
#   19.2,
#   20.7,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '15',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   15.0,
#   13.7,
#   16.4,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '36',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '20',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   19.8,
#   18.9,
#   20.8,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '10',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   164.7,
#   161.1,
#   168.5,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2016,
#   2020,
#   '15',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   11.8,
#   11.1,
#   12.5,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '31',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   252.0,
#   None,
#   None,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '13',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   6.2,
#   5.2,
#   7.2,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '35',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '16',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   26.4,
#   17.0,
#   38.6,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '45',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   44.1,
#   43.0,
#   45.3,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '36',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   38.0,
#   37.5,
#   38.6,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '31',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '4',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   571.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '27',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   11.1,
#   9.5,
#   13.0,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '11',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   10.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '59',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   16.5,
#   16.4,
#   16.7,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '15',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   21.1,
#   18.1,
#   24.5,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '35',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   1222.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '42',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '5',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   497.1,
#   458.5,
#   538.1,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '34',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   168.7,
#   165.4,
#   172.1,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '53',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   20.2,
#   19.6,
#   20.9,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '27',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   380.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '34',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '12',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   427.2,
#   425.7,
#   428.8,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '42',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   16.8,
#   16.4,
#   17.2,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '32',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   104.2,
#   99.3,
#   109.3,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '6',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   22.8,
#   22.5,
#   23.1,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '37',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   12.5,
#   12.1,
#   12.8,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '46',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   1.5,
#   1.1,
#   2.1,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '19',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   46.7,
#   45.2,
#   48.2,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '28',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '40',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   20.3,
#   19.4,
#   21.2,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '9',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   421.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '39',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   6.9,
#   5.4,
#   8.6,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '30',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '11',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '30',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '48',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   19.9,
#   19.6,
#   20.2,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '30',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '54',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   521.3,
#   515.3,
#   527.3,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '23',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '4',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   10.5,
#   8.3,
#   13.1,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '34',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   2.1,
#   1.9,
#   2.3,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '5',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   22.4,
#   20.3,
#   24.5,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '11',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '20',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '11',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   97.0,
#   None,
#   None,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '26',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   477.2,
#   474.7,
#   479.8,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '32',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   332.5,
#   323.2,
#   341.9,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '1',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   406.3,
#   403.1,
#   409.6,
#   'Sex',
#   'Female'),
#  (2016,
#   2020,
#   '27',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   11.1,
#   8.3,
#   14.6,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '44',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   46.9,
#   44.4,
#   49.5,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '26',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   74.3,
#   69.5,
#   79.3,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '41',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   11327.0,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2016,
#   2020,
#   '23',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '21',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   25.7,
#   22.5,
#   29.3,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '26',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   28.4,
#   26.7,
#   30.1,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '34',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   3.3,
#   2.7,
#   3.9,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '13',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   549.8,
#   546.9,
#   552.6,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '10',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   3.8,
#   2.2,
#   6.1,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '11',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   194.5,
#   188.2,
#   201.0,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '12',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   10.6,
#   6.1,
#   17.2,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '19',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   185.3,
#   182.5,
#   188.1,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '9',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   5628.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '17',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   17.7,
#   17.1,
#   18.2,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '17',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   556.5,
#   554.7,
#   558.3,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '50',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   448.4,
#   439.1,
#   458.0,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '31',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   22.0,
#   16.6,
#   28.5,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '22',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '28',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '30',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '33',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '9',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   8.5,
#   8.0,
#   9.0,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '23',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   147.1,
#   113.1,
#   187.0,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '8',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '6',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   7674.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '27',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   522.3,
#   518.6,
#   526.0,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '38',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   144.7,
#   141.1,
#   148.3,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '30',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   22.2,
#   20.5,
#   23.9,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '9',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   18.1,
#   17.3,
#   19.0,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '16',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '17',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   1242.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '15',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   14.5,
#   13.2,
#   15.9,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '1',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '17',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   83.1,
#   80.0,
#   86.3,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '2',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   207.6,
#   193.6,
#   222.3,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '21',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   47.6,
#   40.9,
#   55.1,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '16',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   34.4,
#   32.7,
#   36.2,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '32',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   386.8,
#   383.8,
#   389.8,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '26',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   15.2,
#   11.7,
#   19.1,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '37',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   119.0,
#   None,
#   None,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '16',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '50',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   3837.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '11',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '50',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '33',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '33',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '16',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   13.1,
#   12.3,
#   13.9,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '34',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   16.9,
#   16.3,
#   17.4,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '53',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   1.7,
#   1.5,
#   1.9,
#   'Sex',
#   'Female'),
#  (2016,
#   2020,
#   '27',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   19.6,
#   18.9,
#   20.3,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '11',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   26.9,
#   25.1,
#   28.7,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '51',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '42',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   160.2,
#   159.3,
#   161.0,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '18',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '59',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   178.6,
#   178.0,
#   179.2,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '39',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   1892.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '12',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   466.6,
#   465.4,
#   467.7,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '41',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   13.0,
#   12.5,
#   13.5,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '20',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   34.3,
#   33.1,
#   35.5,
#   'Sex',
#   'Female'),
#  (2016,
#   2020,
#   '31',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   49.2,
#   36.6,
#   64.2,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '54',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '34',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   1.3,
#   0.9,
#   1.9,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '49',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '18',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   13.0,
#   9.8,
#   16.9,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '16',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '35',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '29',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '19',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   31.8,
#   30.8,
#   32.9,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '35',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   372.7,
#   369.3,
#   376.2,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '56',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '53',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   14.3,
#   12.0,
#   16.9,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '8',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   1.5,
#   1.4,
#   1.8,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '46',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   6.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '25',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   415.7,
#   407.3,
#   424.1,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '22',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   16.2,
#   15.3,
#   17.1,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '59',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   15.4,
#   14.4,
#   16.4,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '18',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   44.9,
#   44.2,
#   45.6,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '28',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '13',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   42.8,
#   42.1,
#   43.4,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '24',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   19.5,
#   18.7,
#   20.3,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '15',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '13',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   7.8,
#   6.6,
#   9.3,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '17',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   114.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '25',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   23.3,
#   21.1,
#   25.7,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '42',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   24623.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2016,
#   2020,
#   '23',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   140.8,
#   137.5,
#   144.1,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '27',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   1.2,
#   1.0,
#   1.4,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '28',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   661.9,
#   656.5,
#   667.4,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '4',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   491.7,
#   488.4,
#   495.0,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '33',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '26',
#   'Cancer',
# ...
#   16.6,
#   14.8,
#   18.6,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '29',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   274.9,
#   260.6,
#   289.6,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '35',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '20',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   14.6,
#   11.2,
#   18.6,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '4',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   9.5,
#   6.5,
#   13.2,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '30',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   28.9,
#   16.9,
#   44.8,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '5',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   93.2,
#   78.7,
#   109.3,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '27',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   169.9,
#   167.8,
#   172.0,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '24',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   431.4,
#   428.3,
#   434.4,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '5',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '29',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   14.2,
#   13.8,
#   14.6,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '47',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '20',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   17.3,
#   12.6,
#   23.1,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '16',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   10.8,
#   6.1,
#   17.1,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '15',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   992.0,
#   844.0,
#   1159.5,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '2',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   12.5,
#   11.1,
#   14.1,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '50',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '16',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '6',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   371.0,
#   369.8,
#   372.1,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '59',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   11.0,
#   10.2,
#   11.8,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '34',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   17.7,
#   17.1,
#   18.2,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '37',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   157.4,
#   147.2,
#   168.2,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '13',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   17.2,
#   16.5,
#   17.9,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '31',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   20.1,
#   13.1,
#   29.3,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '24',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   21.0,
#   20.3,
#   21.7,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '20',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   2924.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '12',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   15.1,
#   14.8,
#   15.4,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '35',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   12.0,
#   9.2,
#   15.5,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '55',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   444.6,
#   441.4,
#   447.8,
#   'Sex',
#   'Female'),
#  (2016,
#   2020,
#   '12',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   2116.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '5',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '13',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   8.1,
#   6.8,
#   9.6,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '2',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   99.0,
#   None,
#   None,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '31',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   37.0,
#   35.9,
#   38.2,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2016,
#   2020,
#   '11',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   15.9,
#   13.9,
#   18.2,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '16',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '5',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   14573.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '30',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   19.1,
#   17.6,
#   20.8,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '39',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   178.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '36',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   152.4,
#   150.4,
#   154.4,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '33',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '34',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '2',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   6.6,
#   4.0,
#   10.2,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '6',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   14.6,
#   12.3,
#   17.1,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '10',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '34',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   18.0,
#   16.9,
#   19.1,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2015,
#   2019,
#   '51',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   274.1,
#   246.7,
#   303.9,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '44',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   17.5,
#   16.2,
#   19.0,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '48',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   40.8,
#   40.3,
#   41.3,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '2',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '35',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   456.8,
#   451.1,
#   462.6,
#   'Sex',
#   'Female'),
#  (2016,
#   2020,
#   '21',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '19',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   6131.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '36',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   143.0,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '39',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   645.9,
#   643.6,
#   648.2,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '47',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   205.9,
#   195.2,
#   217.1,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '4',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '13',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   17.1,
#   16.6,
#   17.7,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '10',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   455.9,
#   443.0,
#   469.1,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '8',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   130.4,
#   129.0,
#   131.9,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '2',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '15',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   46.7,
#   38.4,
#   56.1,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2016,
#   2020,
#   '22',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   19.4,
#   18.6,
#   20.2,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '54',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '5',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   64.4,
#   62.7,
#   66.1,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '37',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '5',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '9',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   1.3,
#   1.1,
#   1.5,
#   'Overall',
#   'Overall'),
#  (2016,
#   2020,
#   '29',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '32',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   22.0,
#   21.0,
#   23.0,
#   'Sex',
#   'Female'),
#  (2015,
#   2019,
#   '11',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   35.5,
#   32.4,
#   38.9,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '4',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   18.8,
#   18.1,
#   19.5,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2016,
#   2020,
#   '30',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '30',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   22.2,
#   20.5,
#   23.9,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '23',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '42',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   18.5,
#   18.0,
#   18.9,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '44',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   83.7,
#   74.6,
#   93.4,
#   'Race/Ethnicity',
#   'Hispanic'),
#  (2015,
#   2019,
#   '31',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2016,
#   2020,
#   '5',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2016,
#   2020,
#   '33',
#   'Cancer',
#   'Cervical cancer mortality among all females, underlying cause',
#   None,
#   None,
#   None,
#   'Race/Ethnicity',
#   'Asian or Pacific Islander, non-Hispanic'),
#  (2015,
#   2019,
#   '40',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   4470.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '2',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   50.3,
#   43.6,
#   57.7,
#   'Race/Ethnicity',
#   'American Indian or Alaska Native, non-Hispanic'),
#  (2015,
#   2019,
#   '9',
#   'Cancer',
#   'Breast cancer mortality among all females, underlying cause',
#   22.6,
#   19.8,
#   25.7,
#   'Race/Ethnicity',
#   'Black, non-Hispanic'),
#  (2016,
#   2020,
#   '30',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   42.4,
#   40.7,
#   44.2,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '51',
#   'Cancer',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   3720.0,
#   None,
#   None,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '8',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   13.1,
#   12.5,
#   13.8,
#   'Sex',
#   'Male'),
#  (2016,
#   2020,
#   '17',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   478.9,
#   477.0,
#   480.8,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '24',
#   'Cancer',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   15.8,
#   15.2,
#   16.5,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '30',
#   'Cancer',
#   'Prostate cancer mortality among all males, underlying cause',
#   22.2,
#   20.5,
#   24.0,
#   'Race/Ethnicity',
#   'White, non-Hispanic'),
#  (2015,
#   2019,
#   '40',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   210.1,
#   208.0,
#   212.1,
#   'Overall',
#   'Overall'),
#  (2015,
#   2019,
#   '9',
#   'Cancer',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   164.7,
#   162.1,
#   167.2,
#   'Sex',
#   'Male'),
#  (2015,
#   2019,
#   '11',
#   'Cancer',
#   'Invasive cancer (all sites combined), incidence',
#   1358.0,
#   None,
#   None,
#   'Sex',
#   'Male'),
#  ...]

# %% [markdown]
# ### Connect the two tables with one key that is present in both databases.

# %%
# Create a new combined table
cursor.execute('''
CREATE TABLE IF NOT EXISTS chronic_with_location AS
SELECT 
    cd.YearStart,
    cd.YearEnd,
    cd.Topic,
    cd.Question,
    cd.DataValue,
    cd.LowConfidenceLimit,
    cd.HighConfidenceLimit,
    cd.StratificationCategory1,
    cd.Stratification1,
    l.LocationID,
    l.LocationAbbr,
    l.LocationDesc
FROM chronic_data cd
JOIN locations l ON cd.LocationID = l.LocationID
''')

# %%
# Run the JOIN query using cursor
cursor.execute('''
SELECT cd.YearStart, cd.Topic, cd.Question, cd.DataValue, l.LocationDesc
FROM chronic_data cd
JOIN locations l ON cd.LocationID = l.LocationID
LIMIT 5
''')

# Fetch the results
cursor.fetchall()
# Out:
# [(2019, 'Diabetes', 'Diabetes among adults', 13.6, 'Arkansas'),
#  (2019, 'Diabetes', 'Diabetes among adults', 10.6, 'Idaho'),
#  (2019,
#   'Sleep',
#   'Short sleep duration among high school students',
#   None,
#   'Indiana'),
#  (2019,
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   54.0,
#   'Iowa'),
#  (2019, 'Asthma', 'Current asthma among adults', 10.3, 'Iowa')]

# %%
# Perform JOIN between chronic_data and locations
cursor.execute('''
SELECT 
    cd.YearStart,
    cd.Topic,
    cd.Question,
    cd.DataValue,
    l.LocationDesc
FROM chronic_data cd
JOIN locations l ON cd.LocationID = l.LocationID
LIMIT 5
''')
# Fetch and print the result
cursor.fetchall()
# Out:
# [(2019, 'Diabetes', 'Diabetes among adults', 13.6, 'Arkansas'),
#  (2019, 'Diabetes', 'Diabetes among adults', 10.6, 'Idaho'),
#  (2019,
#   'Sleep',
#   'Short sleep duration among high school students',
#   None,
#   'Indiana'),
#  (2019,
#   'Asthma',
#   'Asthma mortality among all people, underlying cause',
#   54.0,
#   'Iowa'),
#  (2019, 'Asthma', 'Current asthma among adults', 10.3, 'Iowa')]

# %% [markdown]
# ### Remove records with null values from your tables.

# %%
cursor.execute('''
DELETE FROM chronic_data
WHERE YearStart IS NULL OR YearEnd IS NULL OR LocationID IS NULL  OR Topic IS NULL OR Question IS NULL OR
      DataValue IS NULL OR LowConfidenceLimit IS NULL OR HighConfidenceLimit IS NULL OR
      StratificationCategory1 IS NULL OR Stratification1 IS NULL
''')


cursor.execute('''
DELETE FROM locations
WHERE LocationID IS NULL OR LocationAbbr IS NULL OR LocationDesc IS NULL OR Geolocation IS NULL
''')
conn.commit()

# %% [markdown]
# ### Perform two different queries of your data using SQL methods.
# Run Two SQL Queries with Aggregations/Organization

# %%
# Run the query using cursor
cursor.execute('''
SELECT Topic, ROUND(AVG(DataValue), 2) AS AvgValue
FROM chronic_data
GROUP BY Topic
ORDER BY AvgValue DESC
LIMIT 10
''')

# Fetch the results
cursor.fetchall()
# Out:
# [('Cancer', 100.52),
#  ('Maternal Health', 87.88),
#  ('Chronic Obstructive Pulmonary Disease', 78.14),
#  ('Cardiovascular Disease', 76.66),
#  ('Oral Health', 52.55),
#  ('Sleep', 46.79),
#  ('Diabetes', 46.43),
#  ('Immunization', 44.91),
#  ('Social Determinants of Health', 44.61),
#  ('Arthritis', 31.9)]

# %%
# Run the query using cursor
cursor.execute('''
SELECT Topic, ROUND(AVG(DataValue), 2) AS AvgValue
FROM chronic_data
GROUP BY Topic
ORDER BY AvgValue DESC
LIMIT 10
''')

# Fetch the results
cursor.fetchall()
# Out:
# [('Cancer', 100.52),
#  ('Maternal Health', 87.88),
#  ('Chronic Obstructive Pulmonary Disease', 78.14),
#  ('Cardiovascular Disease', 76.66),
#  ('Oral Health', 52.55),
#  ('Sleep', 46.79),
#  ('Diabetes', 46.43),
#  ('Immunization', 44.91),
#  ('Social Determinants of Health', 44.61),
#  ('Arthritis', 31.9)]
